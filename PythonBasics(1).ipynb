# %% [markdown]
# # **Question1)**
#
# 1.   Pyhton is a programming language used to inform computer of what we        actually want to do, as the example which was discussed in the very first lecture, humans need language to cummunicate ideas and thoughts, similarly computer speeks in binary language hence we need an interface that can act as a moderator to convey what we want to speak, here comes prog languages like python that follow well defined rules and structure that basically convey human version of language to computer(binary) to perform and automate various tasks like printing numbers from 1 ot 10 using loops.
#
# 2.   Python is an interpreted based language
#
# 3.   this language has multiple libraries at its disposal enabling a programmer to perform complex tasks using less line of codes
#
#
# 4.   the sytax used in this language is very close to the natural human language
#
# 5.   this language also have a strong community support
#
# hence the above points make this language more popular among freshers and programmers

# %% [markdown]
# #**Question2**)
#
# an interpreter in python is the program that reads and executes Python code. It processes the code line by line, translating each line into machine instructions(binary language) and running them immediately.

# %% [markdown]
# #**Question3)**
#
# Predefined keywords in python are some reserved words that python uses to perform different tasks like print is a keyword in python that prints whatever is written inside it, although these keywords can be used to define a variable in the code but its not a good practise as it messes up the original functionality o fthat key word
#
# as disscussed in the lecture when "print" was used as a variable it was no onger performing the functions as a keyword hence the keywords should not be used to perform tasks it wasn't meant for

# %% [markdown]
# #**Question4)**
#
# as disscussed in the lecture when "print" was used as a variable it was no onger performing the functions as a keyword hence the keywords should not be used to perform tasks it wasn't meant for
#
# although these keywords can be used to define a variable in the code but its not a good practise as it messes up the original functionality of that keyword
# and that line after any line using that keyword will not be executed as expected

# %% [markdown]
# #**Question5)**
#
# mutability of certain data structures in python is their ability to get altered after they are defined for example if a list or dictionary is defined and if any one of their element is accessed and changed the changes are permanently imparted in the original list as well

# %% [markdown]
# #**Question6)**
#
# Tuples immutable to:
#
# 1.  Protect data from being changed by mistake.
#
# 2.  Allow them to be used as dictionary keys or elements in sets
# (which require immutability) as dictionary keys should madatorily be unchangable/immutable.
#
# 3.  immutability help attain some performance optimizations internally.
#
#
# on the other hand
#
# Lists are mutable in python to:
#
# 1.  provide flexibility to change/alter elements efficiently once the data structure is defined

# %% [markdown]
# #**Question7)**
#
# in python "==" operator checks if the vlaues on the either side of it are equal in terms of value or not where as "is" operator checks if a variable is pointing to the same memory location as the other one and return the boolean value as True if both the variables are pointing to the smae memory location else it returns False, for example:
#
# *   a=5
# *   b=a
#
#  here b points to the same memory location as "a" so the output will be "True" in this case

# %% [markdown]
# #**Question8)**
# logical operators in python like and, or , not helps use to implement multiple conditions in if else statements, i.e multiple conditions can be put in if-else statements using these operators that connects them with a logic.

# %% [markdown]
# #**Question10)**
# Typecasting in python helps us to manipulate datatypes of variables holding values of some other different datatype for example:
#
# * a=5 (here a is of type int)
# *   but after typecasting:
# * b=str(5)  this changes the type of 5 as int to a string

# %% [markdown]
# #**Question11)**
# There are two types of typecasting in python implicit and explicit typecasting, in implicity type casting python itself automatically changes the datatype of the value , this is to prevent loss of data for example
#
# * a=5
# * b=2.3
# * print(a+b) the output of this line will be 7.5, pyhton had automatically converted the datatype to float to prevent datatype
#
# explicity typecasting on the other hand if typecasting by explicitly telling python it where we tell python which value should be in which datatype for example
#
# * a=5
# * print(type(str(a)))  #this line will print str eventhpugh the value in a is int as we explicitly mentioned to print a in string type

# %% [markdown]
# #**Question12)**
#
# The elif (short for "else if") statement in Python which allows to check multiple conditions in a sequence when writing conditional logic.
#
# * Python checks conditions from top to bottom.
# * As soon as one condition is True, it runs that block and skips the rest.
# * elif is used only after an if and before an optional else statement.

# %%
#1)
print("hello world")
# Out:
# hello world

# %%
#2)
name="Syed Abdul Mateen"
age=19
print(f"Hi my name is {name} and iam {age} years old")
# Out:
# Hi my name is Syed Abdul Mateen and iam 19 years old

# %%
#3)
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
#4)
import keyword as key
a=input()
if (a not in key.kwlist):
  print(f"{a} is not a keyword!")
else:
  print(f"{a} is a key word!")
# Out:
# False
# False is a key word!

# %%
#5)
a=[1,2,3,4,5]    #--> list
b=(6,7,8,9,10)   #-->tuple

# %%
a[0]='Syed Abdul Mateen'
print(a)
# Out:
# ['Syed Abdul Mateen', 2, 3, 4, 5]

# %%
b[0]="hi"
print(b)   #-->this returns error as tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f503f19ef49a> in <cell line: 0>()
# ----> 1 b[0]="hi"
#       2 print(b)   #-->this returns error as tuples are immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
#7)
a=int(input())
b=int(input())
print(a+b)      #-->by typecsting the string type output from "input" to int we can perform operations on them treating them j
# Out:
# 13
# 56
# 69

# %%
#8)
a=[x for x in range(50)]  #-->this list contains elements from 1 to 50

#iam implementing logical operators to eliminate all multiples of 6 from the list a

for i in a:
  if((i%2==0) and (i%3==0)):
    continue
  print(i,end=" ")

# all the multiples of 6 are eliminated using divisibility rule of 6
# Out:
# 1 2 3 4 5 7 8 9 10 11 13 14 15 16 17 19 20 21 22 23 25 26 27 28 29 31 32 33 34 35 37 38 39 40 41 43 44 45 46 47 49
