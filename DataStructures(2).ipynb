# %% [markdown]
# #**Question 1)**
# Data structures in python is a structure or a way to store and manipulate data efficiently
# there are several data structures inpython like list, tuple, sets and dictionaries

# %% [markdown]
# #**Question 2)**
# mutable data structures are those that can be altered or modified even after they are defined
# * Example:- sets, dictionaries, lists
#
#
#
#
# immutable datatypes in the other hand are those that cannot be altered or modified once they are defined
# * Example:- frozen sets, tuples

# %% [markdown]
# #**Question3)**
#
# * List is a mutable collection of heterogeneous data i.e we can store data of multiple datatypes in a list and also it allows to store duplicate vlaues.
# * lists are unhasable and cannot be usedas keys in dictionaries
# * syntax: my_list=[1,2,3,"Syed Abdul Mateen","Syedda Sumaiyah Azmath","Syed Abdul Rahman"]
# * its slightly slower than tuple
#
# ---
#
# * whereas tuples in python are immutable heterogenous collection of data it als allows to store duplicate vlaues
# * tuples are hasable and can be used as keys in dictionaries
# * syntax: my_tuple=(1,2,3,"Maaz","Zaid","Musa")
# * its slightly faster than list

# %% [markdown]
# #**Question 4)**
# dictionaries in python stores data using (key,value) pairs and the values of the corresponding keys in dictionary is accessed by their respective keys in other words the values in the dictionary basically act as index
# * syntax: my_dict={'a':"Abdul Mateen",'b':"Abdul rahman"}
# * dictionaries are fastes amoung other data structures

# %% [markdown]
# #**Question 5)**
#
# sets in python is used over list if we want to store unique value of evry element and prevent altering already existing individual element by mistake
#
# * sets help prevent modifying already existing elements by not allowing to access elements in the set via index hence we cant modify existing elements in a set
#
# * although the only allowed modifications to a set is we can add new element,
# completely remove existing element, we can update a set with list or a set or a tuple,clear or del entire set from memory
#
# * individual elements in the set cannot be alter as they cannot be accessed in the forst place

# %% [markdown]
# #**Question 6)**
# * string is an immutable data structure in python that stores a group of characters
# * it supports almost all methods/operations that list supports like acessing elements, string slicing, string concatination
# * they are indexed
#
# ---
#
# list on the other hand is a colletion of elements separated by a comma and are mutable

# %% [markdown]
# #**Question 7)**
# tuples in python are immutable and the individual elements in the tuple cannot be altered at any cost hence maintaining the integrity of the data stored
# i.e the data cannot be doped using various methods like in other mutable data structures

# %% [markdown]
# #**Question 8)**
#
# * A hash table is a data structure that stores key-value pairs and allows for fast access to values based on their keys. It uses a hash function to convert the key into an index in an array (or list) where the value is stored.
#
# * Hash table Converts a key into a hash (a number).
#
# * The hash is then mapped to an index in an array.
#
# * hence this property of dictionary that implents hash table make it the fastest and efficient data structure amoung the other ones.

# %% [markdown]
# #**Question 9)**
# yest list in python allows heterogenous data storage it also allows to store duplicate values as well

# %% [markdown]
# #**Question 10)**
# strings in python are immutble to ensure data integrity.

# %% [markdown]
# #**Question 11)**
# * as dictionary offers key based access its quite faster than list
# * Dictionaries allows to access values using meaningful keys (like "name" or "age"), making your data more readable and intuitive.
# * You can retrieve data in a dictionary without knowing its position, unlike lists where you must know the index.
# * Dictionaries automatically prevent duplicate keys, ensuring a clean and organized data structure.
# * Ideal for storing related information (like records or objects), where each value is identified by a specific name.
#
# ---
#
# we use dictionaries when:
# * we need fast, key-based access to data.
# * data is naturally structured in pairs (e.g. name: value).
# * we need clearer, more descriptive code.
#
# we usese lists when:
# * Order matters more than labeling.
# * weneed to store a sequence of items, especially duplicates.
# * we often access items by position (index).

# %% [markdown]
# #**Question 12)**
# * if we donot want our data to get altered i.e mutated then we go for tuples as it is immutable datastructure
# * as tuples are hashable we can use them as keys in dictionary
# ---
# * if we want to alter data after defining it then we use list
# * as list are not hashable we cannot use them as dictionary

# %% [markdown]
# #**Question 13)**
#
# sets completely eliminate any duplicate value passed in it

# %% [markdown]
# #**Question 14)**
# * "in" in list checks if the element is present in the list or not and returns boolean value based on this assertion
#
#
# * whereas "in" in dictionary checks if the key is prensent in the dictionary or not and returns the boolean value based on this assertion

# %% [markdown]
# #**Question 15)**
# no the elements in a tuple cannot be modified as tuples are immutable

# %% [markdown]
# #**Question 16)**
# nested dictionary is the dictionary inside a dictionary
# * one use case od nested dictionary is to store data in json files and then loading it in the form of nested dictionary using load method json module:
# json.load("File_name")

# %% [markdown]
# #**Question 17)**
# since dictionary use hash table for mapping their key value pair time complexity is O(1).

# %% [markdown]
# #**Question 18)**
# if we want to access elements by their position then lists are preffered over dictionaries

# %% [markdown]
# #**Question 19)**
#
# Dictionaries are designed for key-based access, not for accessing elements by their position like lists.
#
# we retrieve values by key, not by their order in the dictionary. hence they are technically unordered

# %% [markdown]
# #**Question 20)**
#
# List follow Position-Based Retrieval
# Data is accessed using integer indexes (starting from 0).
# Slower if searching by value (linear search).
#
# ---
#
# Dictionary follows Key-Based Retrieval
# Data is accessed using unique keys, not positions.
# Very fast (average O(1) time) lookup using keys.

# %%
#1)
a="Syed Abdul Mateen"
a
# Out:
# 'Syed Abdul Mateen'

# %%
#2)
print(len("hello world!"))
# Out:
# 12

# %%
#3)
print("python programming"[0:3])
# Out:
# pyt

# %%
#4)
print("hello".upper())
# Out:
# HELLO

# %%
#5)
a="i like apple"
a.replace("apple","orange")  #-->creates new string as strings are immutable in python it donot change the existing one
# Out:
# 'i like orange'

# %%
#6)
my_list=[i+1 for i in range(5)]
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
#7)
arr=[1,2,3,4]
arr.append(10)
arr
# Out:
# [1, 2, 3, 4, 10]

# %%
#8)
arr1=[1,2,3,4,5]
arr1.remove(3)
arr1
# Out:
# [1, 2, 4, 5]

# %%
#9)
arr2=['a','b','c','d']
arr2[1]
# Out:
# 'b'

# %%
#10)
arr3=[10,20,30,40,50]
arr3[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
#11)
my_tup=tuple((i*100 for i in range(1,4)))
my_tup
# Out:
# (100, 200, 300)

# %%
#12)
tup1=('red', 'green', 'blue', 'yellow')
tup1[-2]
# Out:
# 'blue'

# %%
#13)
tup2=(10,20,5,15)
min(tup2)
# Out:
# 5

# %%
#14)
tup3=('dog', 'cat', 'rabbit')
tup3.index("cat")
# Out:
# 1

# %%
#15)
tup4=("Mango","Orange","Apple")
"kiwi" in tup4
# Out:
# False

# %%
#16)
set1={'a','b','c'}
set1
# Out:
# {'a', 'b'}

# %%
#17)
s={10,20,5,15}
s.clear()
s
# Out:
# set()

# %%
#18)
set2={'a','b','c'}
set2.remove('c')
set2
# Out:
# {'a', 'b'}

# %%
#19)
print( {1, 2, 3} | {3, 4, 5})
# Out:
# {3}

# %%
#20)
print( {1, 2, 3} & {2, 3, 4})
# Out:
# {2, 3}

# %%
#21)
dict1= {"name":"Syed Abdul Mateen", "age":19,  "city":"Waranagl"}
dict1
# Out:
# {'name': 'Syed Abdul Mateen', 'age': 19, 'city': 'Waranagl'}

# %%
#22)
dict2={'name': 'John', 'age': 25}
dict2["country"]= "USA"
dict2
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#23)
dict3= {'name': 'Alice', 'age': 30}
dict3["name"]
# Out:
# 'Alice'

# %%
#24)
dict4= {'name': 'Bob', 'age': 22, 'city': 'New York'}
dict4.pop("age")
dict4
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#25)
dict5= {'name': 'Alice', 'city': 'Paris'}
"city" in dict5
# Out:
# True

# %%
#26)
my_tup=tuple((i*100 for i in range(1,4)))
my_list=[(i+1)*2 for i in range(5)]
my_dict={'name': 'Bob', 'age': 22, 'city': 'New York'}
print(my_tup,type(my_tup))
print(my_list,type(my_list))
print(my_dict,type(my_dict))
# Out:
# (100, 200, 300) <class 'tuple'>
# [2, 4, 6, 8, 10] <class 'list'>
# {'name': 'Bob', 'age': 22, 'city': 'New York'} <class 'dict'>

# %%
#27)
import random

random_numbers = [random.randint(1, 100) for _ in range(5)]
random_numbers.sort()

print("Sorted list:", random_numbers)
# Out:
# Sorted list: [19, 25, 48, 59, 95]

# %%
#28)
li=['name','Bob','age',"hi",'city','New York']
li[2]
# Out:
# 'age'

# %%
#29)
d1={'name': 'Alice', 'city': 'Paris'}
d2={'age': 22,'salary':30000}
d1.update(d2)
d1
# Out:
# {'name': 'Alice', 'city': 'Paris', 'age': 22, 'salary': 30000}

# %%
#30)
li1=['name','Bob','age',"hi",'city','New York']
s1=set(li1)
print(s1,type(s1))
# Out:
# {'city', 'age', 'hi', 'Bob', 'name', 'New York'} <class 'set'>
